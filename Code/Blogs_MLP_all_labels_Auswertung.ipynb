# %% [markdown]
# # Auswertung der Klassifikation mit dem MLPClassifier (all_labels)
#
# Autorin: Maria Hartmann

# %%
# read predicitons
f = open('../MLP/MLP_all_labels_predictions.txt', "r", encoding="utf-8")
lines = f.readlines()
f.close()
trues = []
preds = []
idents = []
labellist = []
for line in lines:
    if line.startswith("TRUE:"):
        line = line.replace("TRUE: ", "").strip()
        #trues.append(line.split(", "))
        labels = line.split(", ")
        tmp_line=[]
        for label in labels:
            label = label.strip().replace(",", "").strip()
            tmp_line.append(label)
        trues.append(tmp_line)
        labellist.append(tmp_line)
        
    elif line.startswith("PRED:"):
        line = line.replace("PRED: ", "").strip()
        #preds.append(line.split(","))
        labels = line.split(", ")
        tmp_line=[]
        for label in labels:
            label = label.strip().replace(",", "").strip()
            tmp_line.append(label)
        preds.append(tmp_line)
        if len(line) != 0:
            labellist.append(tmp_line)
    elif ".txt" in line:
        idents.append(line)
        
    else:
        continue

labelset = sorted(set([item for sublist in labellist for item in sublist]))

# %%
pred_count=0 #Anzal der Vorhersagen insgesamt
label_count=0 # Anzahl der Labels im Testset
false_count=0 # Anzal der falschen Vorhersagen (falsche Vorhersagen sind Vorhersagen, die nicht in den richtigen Labels enthalten sind)
right_count=0 # Anzal der richtigen Vorhersagen
not_pred_count=0 # Anzahl der nicht vorhergesagten Labels
pred_dic=dict(zip(labelset, [0]*len(labelset))) # Vorkommen der Labels in den Vorhersagen
label_dic=dict(zip(labelset, [0]*len(labelset))) # Vorkommen der Labels im Testset
correct_predicted=dict(zip(labelset, [0]*len(labelset))) # Richtige Vorhersagen und ihre Vorkommen
false_predicted=dict(zip(labelset, [0]*len(labelset))) # Falsche Vorhersagen und ihre Vorkommen
not_predicted=dict(zip(labelset, [0]*len(labelset))) # nicht vorhergesagt Labels und die Anzahl ihrer nicht Vorhersagen

for ident, true, pred in zip(idents, trues, preds):
    for t in true:
        label_count+=1
        if t in label_dic:
            label_dic[t]+=1
        else:
            #label_dic[t]=1
            print("Label im Dictionary nicht gefunden")
        if t not in pred:
            not_pred_count+=1
            if t in not_predicted:
                not_predicted[t]+=1
            else:
                #not_predicted[t]=1
                print("Label im Dictionary nicht gefunden")
        else:
            right_count+=1
            if t in correct_predicted:
                correct_predicted[t]+=1
            else:
                #false_predicted[t]=1
                print("Label im Dictionary nicht gefunden")
                
    for p in pred:
        if len(p) != 0:
            pred_count+=1
            if p in pred_dic:
                pred_dic[p]+=1
            else:
                #pred_dic[t]=1
                print("Label im Dictionary nicht gefunden")
            if p not in true:
                false_count+=1
                if p in false_predicted:
                    false_predicted[p]+=1
                else:
                    #false_predicted[p]=1
                    print("Label im Dictionary nicht gefunden")
        else:
            continue

# %%
# Gesamte Labels im Testset
print(len(label_dic))
for k, v in label_dic.items():
    print("%s: %s" % (k, v))
    
#labels = [(k, label_dic[k]) for k in sorted(label_dic, key=label_dic.get, reverse=True)]
#for k, v in labels:
    #print("%s: %s" % (k, v))
# Out:
# 114
# 1914-1918_t: 674
# 1918-1939_t: 24
# 1939-1945_t: 58
# 1945-1989_t: 49
# administration publique et développement_d: 25
# anthropologie politique_t: 25
# approches de corpus_t: 1412
# archives_t: 1412
# archéologie_d: 45
# arts et humanités_d: 389
# arts_d: 27
# asie_t: 67
# bas moyen âge_t: 212
# bibliothéconomie_d: 85
# biomédecine_d: 42
# chine_t: 30
# communication_d: 170
# conflits_t: 36
# digital humanities_t: 196
# enquêtes_t: 1412
# europe centrale et orientale_t: 80
# europe_t: 86
# france_t: 107
# guerres_t: 36
# haut moyen âge_t: 240
# histoire culturelle_t: 209
# histoire de l'art_t: 120
# histoire des religions_t: 88
# histoire des sciences sociales_d: 46
# histoire des sciences_t: 100
# histoire du droit_t: 44
# histoire et archéologie_d: 1978
# histoire et philosophie des sciences_d: 136
# histoire et sociologie des médias_t: 134
# histoire industrielle_t: 22
# histoire intellectuelle_t: 146
# histoire politique_t: 35
# histoire sociale_t: 162
# histoire urbaine_t: 111
# histoire économique_t: 28
# histoire_d: 1427
# histoire_t: 2677
# historiographie_t: 32
# humanités pluridisciplinaires_d: 614
# information_t: 302
# langage_t: 27
# langue et linguistique_d: 80
# linguistique appliquée_d: 27
# linguistique_t: 60
# littérature_d: 42
# littératures_t: 39
# monde germanique_t: 478
# moyen âge_t: 211
# musique_d: 36
# méthodes de traitement et de représentation_t: 28
# patrimoine_t: 245
# pays baltes et scandinaves_t: 33
# pensée_t: 28
# philosophie_d: 34
# philosophie_t: 27
# pluridisciplinarité_d: 621
# prospectives_t: 160
# psychisme_t: 50
# psychologie expérimentale_d: 22
# psychologie_d: 28
# psychologie_t: 46
# relations internationales_t: 22
# religions_d: 151
# religions_t: 44
# représentations_t: 217
# révolution française_t: 53
# sciences auxiliaires de l'histoire_t: 117
# sciences cognitives_t: 22
# sciences de l'information et bibliothéconomie_d: 53
# sciences de l'information et de la communication_d: 85
# sciences de l'information_t: 98
# sciences de l'éducation_t: 56
# sciences politiques_d: 114
# sciences sociales interdisciplinaires_d: 1846
# sociologie de la culture_t: 163
# sociologie des religions_t: 28
# sociologie des sciences_t: 93
# sociologie du travail_t: 155
# sociologie et anthropologie_d: 127
# sociologie urbaine_t: 125
# sociologie économique_t: 108
# sociologie_d: 101
# sociologie_t: 113
# travail social et politique sociale_d: 28
# travail social_d: 53
# vie de la recherche_t: 93
# violence_t: 36
# xvie siècle_t: 49
# xviie siècle_t: 251
# xviiie siècle_t: 212
# xxe siècle_t: 39
# xxie siècle_t: 45
# âges de la vie_t: 50
# économie_d: 21
# édition électronique_t: 208
# éducation et sciences de l'éducation_d: 27
# éducation spécialisée_d: 77
# éducation_d: 155
# éducation_t: 97
# épistémologie et méthodes_t: 112
# époque contemporaine_t: 730
# époque moderne_t: 138
# étude des genres_t: 42
# études anciennes_d: 34
# études asiatiques_d: 54
# études des sciences_t: 148
# études régionales_d: 46
# études sur la famille_d: 28
# études visuelles_t: 75

# %%
# Gesamte Vorhersagen im Testset
print(len(pred_dic))
for k, v in pred_dic.items():
    print("%s: %s" % (k, v))
# Out:
# 114
# 1914-1918_t: 628
# 1918-1939_t: 9
# 1939-1945_t: 30
# 1945-1989_t: 31
# administration publique et développement_d: 14
# anthropologie politique_t: 16
# approches de corpus_t: 1219
# archives_t: 1234
# archéologie_d: 28
# arts et humanités_d: 280
# arts_d: 12
# asie_t: 46
# bas moyen âge_t: 178
# bibliothéconomie_d: 27
# biomédecine_d: 26
# chine_t: 9
# communication_d: 81
# conflits_t: 18
# digital humanities_t: 130
# enquêtes_t: 1232
# europe centrale et orientale_t: 49
# europe_t: 49
# france_t: 49
# guerres_t: 18
# haut moyen âge_t: 223
# histoire culturelle_t: 148
# histoire de l'art_t: 80
# histoire des religions_t: 46
# histoire des sciences sociales_d: 8
# histoire des sciences_t: 58
# histoire du droit_t: 28
# histoire et archéologie_d: 1947
# histoire et philosophie des sciences_d: 90
# histoire et sociologie des médias_t: 67
# histoire industrielle_t: 0
# histoire intellectuelle_t: 78
# histoire politique_t: 4
# histoire sociale_t: 64
# histoire urbaine_t: 53
# histoire économique_t: 0
# histoire_d: 1357
# histoire_t: 2716
# historiographie_t: 18
# humanités pluridisciplinaires_d: 466
# information_t: 256
# langage_t: 12
# langue et linguistique_d: 44
# linguistique appliquée_d: 12
# linguistique_t: 28
# littérature_d: 18
# littératures_t: 21
# monde germanique_t: 415
# moyen âge_t: 161
# musique_d: 12
# méthodes de traitement et de représentation_t: 19
# patrimoine_t: 167
# pays baltes et scandinaves_t: 23
# pensée_t: 9
# philosophie_d: 19
# philosophie_t: 9
# pluridisciplinarité_d: 534
# prospectives_t: 53
# psychisme_t: 39
# psychologie expérimentale_d: 9
# psychologie_d: 20
# psychologie_t: 31
# relations internationales_t: 1
# religions_d: 85
# religions_t: 33
# représentations_t: 125
# révolution française_t: 23
# sciences auxiliaires de l'histoire_t: 87
# sciences cognitives_t: 9
# sciences de l'information et bibliothéconomie_d: 21
# sciences de l'information et de la communication_d: 27
# sciences de l'information_t: 55
# sciences de l'éducation_t: 40
# sciences politiques_d: 61
# sciences sociales interdisciplinaires_d: 1882
# sociologie de la culture_t: 102
# sociologie des religions_t: 19
# sociologie des sciences_t: 56
# sociologie du travail_t: 124
# sociologie et anthropologie_d: 74
# sociologie urbaine_t: 86
# sociologie économique_t: 68
# sociologie_d: 51
# sociologie_t: 84
# travail social et politique sociale_d: 26
# travail social_d: 41
# vie de la recherche_t: 59
# violence_t: 18
# xvie siècle_t: 9
# xviie siècle_t: 200
# xviiie siècle_t: 152
# xxe siècle_t: 6
# xxie siècle_t: 28
# âges de la vie_t: 38
# économie_d: 2
# édition électronique_t: 124
# éducation et sciences de l'éducation_d: 8
# éducation spécialisée_d: 54
# éducation_d: 98
# éducation_t: 56
# épistémologie et méthodes_t: 59
# époque contemporaine_t: 641
# époque moderne_t: 83
# étude des genres_t: 26
# études anciennes_d: 9
# études asiatiques_d: 36
# études des sciences_t: 97
# études régionales_d: 25
# études sur la famille_d: 4
# études visuelles_t: 40

# %%
# Korrekte Vorhersagen je Label im Korpus
print(len(correct_predicted))
for k, v in correct_predicted.items():
    print("%s: %s" % (k, v))
# Out:
# 114
# 1914-1918_t: 612
# 1918-1939_t: 9
# 1939-1945_t: 26
# 1945-1989_t: 28
# administration publique et développement_d: 12
# anthropologie politique_t: 11
# approches de corpus_t: 1110
# archives_t: 1119
# archéologie_d: 23
# arts et humanités_d: 219
# arts_d: 12
# asie_t: 46
# bas moyen âge_t: 122
# bibliothéconomie_d: 26
# biomédecine_d: 26
# chine_t: 8
# communication_d: 69
# conflits_t: 17
# digital humanities_t: 100
# enquêtes_t: 1116
# europe centrale et orientale_t: 45
# europe_t: 42
# france_t: 40
# guerres_t: 17
# haut moyen âge_t: 155
# histoire culturelle_t: 123
# histoire de l'art_t: 69
# histoire des religions_t: 42
# histoire des sciences sociales_d: 8
# histoire des sciences_t: 55
# histoire du droit_t: 28
# histoire et archéologie_d: 1660
# histoire et philosophie des sciences_d: 59
# histoire et sociologie des médias_t: 57
# histoire industrielle_t: 0
# histoire intellectuelle_t: 65
# histoire politique_t: 4
# histoire sociale_t: 47
# histoire urbaine_t: 46
# histoire économique_t: 0
# histoire_d: 1155
# histoire_t: 2455
# historiographie_t: 13
# humanités pluridisciplinaires_d: 355
# information_t: 186
# langage_t: 11
# langue et linguistique_d: 42
# linguistique appliquée_d: 11
# linguistique_t: 26
# littérature_d: 18
# littératures_t: 20
# monde germanique_t: 298
# moyen âge_t: 140
# musique_d: 11
# méthodes de traitement et de représentation_t: 19
# patrimoine_t: 117
# pays baltes et scandinaves_t: 23
# pensée_t: 8
# philosophie_d: 17
# philosophie_t: 9
# pluridisciplinarité_d: 379
# prospectives_t: 43
# psychisme_t: 38
# psychologie expérimentale_d: 9
# psychologie_d: 20
# psychologie_t: 30
# relations internationales_t: 1
# religions_d: 71
# religions_t: 32
# représentations_t: 104
# révolution française_t: 22
# sciences auxiliaires de l'histoire_t: 62
# sciences cognitives_t: 9
# sciences de l'information et bibliothéconomie_d: 21
# sciences de l'information et de la communication_d: 26
# sciences de l'information_t: 43
# sciences de l'éducation_t: 35
# sciences politiques_d: 49
# sciences sociales interdisciplinaires_d: 1576
# sociologie de la culture_t: 89
# sociologie des religions_t: 16
# sociologie des sciences_t: 46
# sociologie du travail_t: 104
# sociologie et anthropologie_d: 66
# sociologie urbaine_t: 77
# sociologie économique_t: 63
# sociologie_d: 41
# sociologie_t: 73
# travail social et politique sociale_d: 22
# travail social_d: 39
# vie de la recherche_t: 54
# violence_t: 17
# xvie siècle_t: 9
# xviie siècle_t: 143
# xviiie siècle_t: 109
# xxe siècle_t: 5
# xxie siècle_t: 28
# âges de la vie_t: 33
# économie_d: 2
# édition électronique_t: 98
# éducation et sciences de l'éducation_d: 7
# éducation spécialisée_d: 50
# éducation_d: 86
# éducation_t: 50
# épistémologie et méthodes_t: 52
# époque contemporaine_t: 617
# époque moderne_t: 74
# étude des genres_t: 26
# études anciennes_d: 9
# études asiatiques_d: 34
# études des sciences_t: 77
# études régionales_d: 25
# études sur la famille_d: 4
# études visuelles_t: 39

# %%
# Falsche Vorhersagen je Label im Korpus
print(len(false_predicted))
for k, v in false_predicted.items():
    print("%s: %s" % (k, v))
# Out:
# 114
# 1914-1918_t: 16
# 1918-1939_t: 0
# 1939-1945_t: 4
# 1945-1989_t: 3
# administration publique et développement_d: 2
# anthropologie politique_t: 5
# approches de corpus_t: 109
# archives_t: 115
# archéologie_d: 5
# arts et humanités_d: 61
# arts_d: 0
# asie_t: 0
# bas moyen âge_t: 56
# bibliothéconomie_d: 1
# biomédecine_d: 0
# chine_t: 1
# communication_d: 12
# conflits_t: 1
# digital humanities_t: 30
# enquêtes_t: 116
# europe centrale et orientale_t: 4
# europe_t: 7
# france_t: 9
# guerres_t: 1
# haut moyen âge_t: 68
# histoire culturelle_t: 25
# histoire de l'art_t: 11
# histoire des religions_t: 4
# histoire des sciences sociales_d: 0
# histoire des sciences_t: 3
# histoire du droit_t: 0
# histoire et archéologie_d: 287
# histoire et philosophie des sciences_d: 31
# histoire et sociologie des médias_t: 10
# histoire industrielle_t: 0
# histoire intellectuelle_t: 13
# histoire politique_t: 0
# histoire sociale_t: 17
# histoire urbaine_t: 7
# histoire économique_t: 0
# histoire_d: 202
# histoire_t: 261
# historiographie_t: 5
# humanités pluridisciplinaires_d: 111
# information_t: 70
# langage_t: 1
# langue et linguistique_d: 2
# linguistique appliquée_d: 1
# linguistique_t: 2
# littérature_d: 0
# littératures_t: 1
# monde germanique_t: 117
# moyen âge_t: 21
# musique_d: 1
# méthodes de traitement et de représentation_t: 0
# patrimoine_t: 50
# pays baltes et scandinaves_t: 0
# pensée_t: 1
# philosophie_d: 2
# philosophie_t: 0
# pluridisciplinarité_d: 155
# prospectives_t: 10
# psychisme_t: 1
# psychologie expérimentale_d: 0
# psychologie_d: 0
# psychologie_t: 1
# relations internationales_t: 0
# religions_d: 14
# religions_t: 1
# représentations_t: 21
# révolution française_t: 1
# sciences auxiliaires de l'histoire_t: 25
# sciences cognitives_t: 0
# sciences de l'information et bibliothéconomie_d: 0
# sciences de l'information et de la communication_d: 1
# sciences de l'information_t: 12
# sciences de l'éducation_t: 5
# sciences politiques_d: 12
# sciences sociales interdisciplinaires_d: 306
# sociologie de la culture_t: 13
# sociologie des religions_t: 3
# sociologie des sciences_t: 10
# sociologie du travail_t: 20
# sociologie et anthropologie_d: 8
# sociologie urbaine_t: 9
# sociologie économique_t: 5
# sociologie_d: 10
# sociologie_t: 11
# travail social et politique sociale_d: 4
# travail social_d: 2
# vie de la recherche_t: 5
# violence_t: 1
# xvie siècle_t: 0
# xviie siècle_t: 57
# xviiie siècle_t: 43
# xxe siècle_t: 1
# xxie siècle_t: 0
# âges de la vie_t: 5
# économie_d: 0
# édition électronique_t: 26
# éducation et sciences de l'éducation_d: 1
# éducation spécialisée_d: 4
# éducation_d: 12
# éducation_t: 6
# épistémologie et méthodes_t: 7
# époque contemporaine_t: 24
# époque moderne_t: 9
# étude des genres_t: 0
# études anciennes_d: 0
# études asiatiques_d: 2
# études des sciences_t: 20
# études régionales_d: 0
# études sur la famille_d: 0
# études visuelles_t: 1

# %%
# nicht vorhergesagte Labels im Korpus
print(len(not_predicted))
for k, v in not_predicted.items():
    print("%s: %s" % (k, v))
# Out:
# 114
# 1914-1918_t: 62
# 1918-1939_t: 15
# 1939-1945_t: 32
# 1945-1989_t: 21
# administration publique et développement_d: 13
# anthropologie politique_t: 14
# approches de corpus_t: 302
# archives_t: 293
# archéologie_d: 22
# arts et humanités_d: 170
# arts_d: 15
# asie_t: 21
# bas moyen âge_t: 90
# bibliothéconomie_d: 59
# biomédecine_d: 16
# chine_t: 22
# communication_d: 101
# conflits_t: 19
# digital humanities_t: 96
# enquêtes_t: 296
# europe centrale et orientale_t: 35
# europe_t: 44
# france_t: 67
# guerres_t: 19
# haut moyen âge_t: 85
# histoire culturelle_t: 86
# histoire de l'art_t: 51
# histoire des religions_t: 46
# histoire des sciences sociales_d: 38
# histoire des sciences_t: 45
# histoire du droit_t: 16
# histoire et archéologie_d: 318
# histoire et philosophie des sciences_d: 77
# histoire et sociologie des médias_t: 77
# histoire industrielle_t: 22
# histoire intellectuelle_t: 81
# histoire politique_t: 31
# histoire sociale_t: 115
# histoire urbaine_t: 65
# histoire économique_t: 28
# histoire_d: 272
# histoire_t: 222
# historiographie_t: 19
# humanités pluridisciplinaires_d: 259
# information_t: 116
# langage_t: 16
# langue et linguistique_d: 38
# linguistique appliquée_d: 16
# linguistique_t: 34
# littérature_d: 24
# littératures_t: 19
# monde germanique_t: 180
# moyen âge_t: 71
# musique_d: 25
# méthodes de traitement et de représentation_t: 9
# patrimoine_t: 128
# pays baltes et scandinaves_t: 10
# pensée_t: 20
# philosophie_d: 17
# philosophie_t: 18
# pluridisciplinarité_d: 242
# prospectives_t: 117
# psychisme_t: 12
# psychologie expérimentale_d: 13
# psychologie_d: 8
# psychologie_t: 16
# relations internationales_t: 21
# religions_d: 80
# religions_t: 12
# représentations_t: 113
# révolution française_t: 31
# sciences auxiliaires de l'histoire_t: 55
# sciences cognitives_t: 13
# sciences de l'information et bibliothéconomie_d: 32
# sciences de l'information et de la communication_d: 59
# sciences de l'information_t: 55
# sciences de l'éducation_t: 21
# sciences politiques_d: 65
# sciences sociales interdisciplinaires_d: 270
# sociologie de la culture_t: 74
# sociologie des religions_t: 12
# sociologie des sciences_t: 47
# sociologie du travail_t: 51
# sociologie et anthropologie_d: 61
# sociologie urbaine_t: 48
# sociologie économique_t: 45
# sociologie_d: 60
# sociologie_t: 40
# travail social et politique sociale_d: 6
# travail social_d: 14
# vie de la recherche_t: 39
# violence_t: 19
# xvie siècle_t: 40
# xviie siècle_t: 108
# xviiie siècle_t: 103
# xxe siècle_t: 34
# xxie siècle_t: 17
# âges de la vie_t: 17
# économie_d: 19
# édition électronique_t: 110
# éducation et sciences de l'éducation_d: 20
# éducation spécialisée_d: 27
# éducation_d: 69
# éducation_t: 47
# épistémologie et méthodes_t: 60
# époque contemporaine_t: 113
# époque moderne_t: 64
# étude des genres_t: 16
# études anciennes_d: 25
# études asiatiques_d: 20
# études des sciences_t: 71
# études régionales_d: 21
# études sur la famille_d: 24
# études visuelles_t: 36

# %% [markdown]
# PROZENTUALE AUSWERTUNG:
#
# Prozentsatz = (Prozentwert/Grundwert)*100
#
#
# label_dic = correct_predicted + not_predicted
#
# pred_dic = correct_predicted + false_predicted

# %%
# nicht vorhergesagte Labels in Prozent
not_predicted_prozent={}
for key, value in label_dic.items():
    for not_k, not_v in not_predicted.items():
        if not_k == key:
            prozent=round(((not_v/value)*100),2)
            not_predicted_prozent[not_k]=prozent
            
for k, v in not_predicted_prozent.items():
    print("%s: %s%%" % (k, v))
# Out:
# 1914-1918_t: 9.2%
# 1918-1939_t: 62.5%
# 1939-1945_t: 55.17%
# 1945-1989_t: 42.86%
# administration publique et développement_d: 52.0%
# anthropologie politique_t: 56.0%
# approches de corpus_t: 21.39%
# archives_t: 20.75%
# archéologie_d: 48.89%
# arts et humanités_d: 43.7%
# arts_d: 55.56%
# asie_t: 31.34%
# bas moyen âge_t: 42.45%
# bibliothéconomie_d: 69.41%
# biomédecine_d: 38.1%
# chine_t: 73.33%
# communication_d: 59.41%
# conflits_t: 52.78%
# digital humanities_t: 48.98%
# enquêtes_t: 20.96%
# europe centrale et orientale_t: 43.75%
# europe_t: 51.16%
# france_t: 62.62%
# guerres_t: 52.78%
# haut moyen âge_t: 35.42%
# histoire culturelle_t: 41.15%
# histoire de l'art_t: 42.5%
# histoire des religions_t: 52.27%
# histoire des sciences sociales_d: 82.61%
# histoire des sciences_t: 45.0%
# histoire du droit_t: 36.36%
# histoire et archéologie_d: 16.08%
# histoire et philosophie des sciences_d: 56.62%
# histoire et sociologie des médias_t: 57.46%
# histoire industrielle_t: 100.0%
# histoire intellectuelle_t: 55.48%
# histoire politique_t: 88.57%
# histoire sociale_t: 70.99%
# histoire urbaine_t: 58.56%
# histoire économique_t: 100.0%
# histoire_d: 19.06%
# histoire_t: 8.29%
# historiographie_t: 59.38%
# humanités pluridisciplinaires_d: 42.18%
# information_t: 38.41%
# langage_t: 59.26%
# langue et linguistique_d: 47.5%
# linguistique appliquée_d: 59.26%
# linguistique_t: 56.67%
# littérature_d: 57.14%
# littératures_t: 48.72%
# monde germanique_t: 37.66%
# moyen âge_t: 33.65%
# musique_d: 69.44%
# méthodes de traitement et de représentation_t: 32.14%
# patrimoine_t: 52.24%
# pays baltes et scandinaves_t: 30.3%
# pensée_t: 71.43%
# philosophie_d: 50.0%
# philosophie_t: 66.67%
# pluridisciplinarité_d: 38.97%
# prospectives_t: 73.12%
# psychisme_t: 24.0%
# psychologie expérimentale_d: 59.09%
# psychologie_d: 28.57%
# psychologie_t: 34.78%
# relations internationales_t: 95.45%
# religions_d: 52.98%
# religions_t: 27.27%
# représentations_t: 52.07%
# révolution française_t: 58.49%
# sciences auxiliaires de l'histoire_t: 47.01%
# sciences cognitives_t: 59.09%
# sciences de l'information et bibliothéconomie_d: 60.38%
# sciences de l'information et de la communication_d: 69.41%
# sciences de l'information_t: 56.12%
# sciences de l'éducation_t: 37.5%
# sciences politiques_d: 57.02%
# sciences sociales interdisciplinaires_d: 14.63%
# sociologie de la culture_t: 45.4%
# sociologie des religions_t: 42.86%
# sociologie des sciences_t: 50.54%
# sociologie du travail_t: 32.9%
# sociologie et anthropologie_d: 48.03%
# sociologie urbaine_t: 38.4%
# sociologie économique_t: 41.67%
# sociologie_d: 59.41%
# sociologie_t: 35.4%
# travail social et politique sociale_d: 21.43%
# travail social_d: 26.42%
# vie de la recherche_t: 41.94%
# violence_t: 52.78%
# xvie siècle_t: 81.63%
# xviie siècle_t: 43.03%
# xviiie siècle_t: 48.58%
# xxe siècle_t: 87.18%
# xxie siècle_t: 37.78%
# âges de la vie_t: 34.0%
# économie_d: 90.48%
# édition électronique_t: 52.88%
# éducation et sciences de l'éducation_d: 74.07%
# éducation spécialisée_d: 35.06%
# éducation_d: 44.52%
# éducation_t: 48.45%
# épistémologie et méthodes_t: 53.57%
# époque contemporaine_t: 15.48%
# époque moderne_t: 46.38%
# étude des genres_t: 38.1%
# études anciennes_d: 73.53%
# études asiatiques_d: 37.04%
# études des sciences_t: 47.97%
# études régionales_d: 45.65%
# études sur la famille_d: 85.71%
# études visuelles_t: 48.0%

# %%
# Fehlklassifizierungsrate je Label in Prozent
false_predicted_prozent={}
for key, value in pred_dic.items():
    for false_k, false_v in false_predicted.items():
        if false_k == key:
            if value != 0:
                prozent=round(((false_v/value)*100),2)
                false_predicted_prozent[false_k]=prozent
            else:
                false_predicted_prozent[false_k]=0
for k, v in false_predicted_prozent.items():
    print("%s: %s%%" % (k, v))
# Out:
# 1914-1918_t: 2.55%
# 1918-1939_t: 0.0%
# 1939-1945_t: 13.33%
# 1945-1989_t: 9.68%
# administration publique et développement_d: 14.29%
# anthropologie politique_t: 31.25%
# approches de corpus_t: 8.94%
# archives_t: 9.32%
# archéologie_d: 17.86%
# arts et humanités_d: 21.79%
# arts_d: 0.0%
# asie_t: 0.0%
# bas moyen âge_t: 31.46%
# bibliothéconomie_d: 3.7%
# biomédecine_d: 0.0%
# chine_t: 11.11%
# communication_d: 14.81%
# conflits_t: 5.56%
# digital humanities_t: 23.08%
# enquêtes_t: 9.42%
# europe centrale et orientale_t: 8.16%
# europe_t: 14.29%
# france_t: 18.37%
# guerres_t: 5.56%
# haut moyen âge_t: 30.49%
# histoire culturelle_t: 16.89%
# histoire de l'art_t: 13.75%
# histoire des religions_t: 8.7%
# histoire des sciences sociales_d: 0.0%
# histoire des sciences_t: 5.17%
# histoire du droit_t: 0.0%
# histoire et archéologie_d: 14.74%
# histoire et philosophie des sciences_d: 34.44%
# histoire et sociologie des médias_t: 14.93%
# histoire industrielle_t: 0%
# histoire intellectuelle_t: 16.67%
# histoire politique_t: 0.0%
# histoire sociale_t: 26.56%
# histoire urbaine_t: 13.21%
# histoire économique_t: 0%
# histoire_d: 14.89%
# histoire_t: 9.61%
# historiographie_t: 27.78%
# humanités pluridisciplinaires_d: 23.82%
# information_t: 27.34%
# langage_t: 8.33%
# langue et linguistique_d: 4.55%
# linguistique appliquée_d: 8.33%
# linguistique_t: 7.14%
# littérature_d: 0.0%
# littératures_t: 4.76%
# monde germanique_t: 28.19%
# moyen âge_t: 13.04%
# musique_d: 8.33%
# méthodes de traitement et de représentation_t: 0.0%
# patrimoine_t: 29.94%
# pays baltes et scandinaves_t: 0.0%
# pensée_t: 11.11%
# philosophie_d: 10.53%
# philosophie_t: 0.0%
# pluridisciplinarité_d: 29.03%
# prospectives_t: 18.87%
# psychisme_t: 2.56%
# psychologie expérimentale_d: 0.0%
# psychologie_d: 0.0%
# psychologie_t: 3.23%
# relations internationales_t: 0.0%
# religions_d: 16.47%
# religions_t: 3.03%
# représentations_t: 16.8%
# révolution française_t: 4.35%
# sciences auxiliaires de l'histoire_t: 28.74%
# sciences cognitives_t: 0.0%
# sciences de l'information et bibliothéconomie_d: 0.0%
# sciences de l'information et de la communication_d: 3.7%
# sciences de l'information_t: 21.82%
# sciences de l'éducation_t: 12.5%
# sciences politiques_d: 19.67%
# sciences sociales interdisciplinaires_d: 16.26%
# sociologie de la culture_t: 12.75%
# sociologie des religions_t: 15.79%
# sociologie des sciences_t: 17.86%
# sociologie du travail_t: 16.13%
# sociologie et anthropologie_d: 10.81%
# sociologie urbaine_t: 10.47%
# sociologie économique_t: 7.35%
# sociologie_d: 19.61%
# sociologie_t: 13.1%
# travail social et politique sociale_d: 15.38%
# travail social_d: 4.88%
# vie de la recherche_t: 8.47%
# violence_t: 5.56%
# xvie siècle_t: 0.0%
# xviie siècle_t: 28.5%
# xviiie siècle_t: 28.29%
# xxe siècle_t: 16.67%
# xxie siècle_t: 0.0%
# âges de la vie_t: 13.16%
# économie_d: 0.0%
# édition électronique_t: 20.97%
# éducation et sciences de l'éducation_d: 12.5%
# éducation spécialisée_d: 7.41%
# éducation_d: 12.24%
# éducation_t: 10.71%
# épistémologie et méthodes_t: 11.86%
# époque contemporaine_t: 3.74%
# époque moderne_t: 10.84%
# étude des genres_t: 0.0%
# études anciennes_d: 0.0%
# études asiatiques_d: 5.56%
# études des sciences_t: 20.62%
# études régionales_d: 0.0%
# études sur la famille_d: 0.0%
# études visuelles_t: 2.5%

# %%
# Korrektklassifizierungsrate je Label in Prozent
correct_predicted_prozent={}
for key, value in pred_dic.items():
    for correct_k, correct_v in correct_predicted.items():
        if correct_k == key:
            if value != 0:
                prozent=round(((correct_v/value)*100),2)
                correct_predicted_prozent[correct_k]=prozent
            else:
                correct_predicted_prozent[correct_k]=0
for k, v in correct_predicted_prozent.items():
    print("%s: %s%%" % (k, v))
# Out:
# 1914-1918_t: 97.45%
# 1918-1939_t: 100.0%
# 1939-1945_t: 86.67%
# 1945-1989_t: 90.32%
# administration publique et développement_d: 85.71%
# anthropologie politique_t: 68.75%
# approches de corpus_t: 91.06%
# archives_t: 90.68%
# archéologie_d: 82.14%
# arts et humanités_d: 78.21%
# arts_d: 100.0%
# asie_t: 100.0%
# bas moyen âge_t: 68.54%
# bibliothéconomie_d: 96.3%
# biomédecine_d: 100.0%
# chine_t: 88.89%
# communication_d: 85.19%
# conflits_t: 94.44%
# digital humanities_t: 76.92%
# enquêtes_t: 90.58%
# europe centrale et orientale_t: 91.84%
# europe_t: 85.71%
# france_t: 81.63%
# guerres_t: 94.44%
# haut moyen âge_t: 69.51%
# histoire culturelle_t: 83.11%
# histoire de l'art_t: 86.25%
# histoire des religions_t: 91.3%
# histoire des sciences sociales_d: 100.0%
# histoire des sciences_t: 94.83%
# histoire du droit_t: 100.0%
# histoire et archéologie_d: 85.26%
# histoire et philosophie des sciences_d: 65.56%
# histoire et sociologie des médias_t: 85.07%
# histoire industrielle_t: 0%
# histoire intellectuelle_t: 83.33%
# histoire politique_t: 100.0%
# histoire sociale_t: 73.44%
# histoire urbaine_t: 86.79%
# histoire économique_t: 0%
# histoire_d: 85.11%
# histoire_t: 90.39%
# historiographie_t: 72.22%
# humanités pluridisciplinaires_d: 76.18%
# information_t: 72.66%
# langage_t: 91.67%
# langue et linguistique_d: 95.45%
# linguistique appliquée_d: 91.67%
# linguistique_t: 92.86%
# littérature_d: 100.0%
# littératures_t: 95.24%
# monde germanique_t: 71.81%
# moyen âge_t: 86.96%
# musique_d: 91.67%
# méthodes de traitement et de représentation_t: 100.0%
# patrimoine_t: 70.06%
# pays baltes et scandinaves_t: 100.0%
# pensée_t: 88.89%
# philosophie_d: 89.47%
# philosophie_t: 100.0%
# pluridisciplinarité_d: 70.97%
# prospectives_t: 81.13%
# psychisme_t: 97.44%
# psychologie expérimentale_d: 100.0%
# psychologie_d: 100.0%
# psychologie_t: 96.77%
# relations internationales_t: 100.0%
# religions_d: 83.53%
# religions_t: 96.97%
# représentations_t: 83.2%
# révolution française_t: 95.65%
# sciences auxiliaires de l'histoire_t: 71.26%
# sciences cognitives_t: 100.0%
# sciences de l'information et bibliothéconomie_d: 100.0%
# sciences de l'information et de la communication_d: 96.3%
# sciences de l'information_t: 78.18%
# sciences de l'éducation_t: 87.5%
# sciences politiques_d: 80.33%
# sciences sociales interdisciplinaires_d: 83.74%
# sociologie de la culture_t: 87.25%
# sociologie des religions_t: 84.21%
# sociologie des sciences_t: 82.14%
# sociologie du travail_t: 83.87%
# sociologie et anthropologie_d: 89.19%
# sociologie urbaine_t: 89.53%
# sociologie économique_t: 92.65%
# sociologie_d: 80.39%
# sociologie_t: 86.9%
# travail social et politique sociale_d: 84.62%
# travail social_d: 95.12%
# vie de la recherche_t: 91.53%
# violence_t: 94.44%
# xvie siècle_t: 100.0%
# xviie siècle_t: 71.5%
# xviiie siècle_t: 71.71%
# xxe siècle_t: 83.33%
# xxie siècle_t: 100.0%
# âges de la vie_t: 86.84%
# économie_d: 100.0%
# édition électronique_t: 79.03%
# éducation et sciences de l'éducation_d: 87.5%
# éducation spécialisée_d: 92.59%
# éducation_d: 87.76%
# éducation_t: 89.29%
# épistémologie et méthodes_t: 88.14%
# époque contemporaine_t: 96.26%
# époque moderne_t: 89.16%
# étude des genres_t: 100.0%
# études anciennes_d: 100.0%
# études asiatiques_d: 94.44%
# études des sciences_t: 79.38%
# études régionales_d: 100.0%
# études sur la famille_d: 100.0%
# études visuelles_t: 97.5%

# %% [markdown]
# Ergebnisse in Datei schreiben

# %%
f = open('../Preprocessing/blogposts_per_all_labels_reduced.txt', "r", encoding="utf-8")
lines = f.readlines()
f.close()

label_train_dic=dict(zip(labelset, [0]*len(labelset))) # Vorkommen der Labels im Testset

for line in lines:
    label, count = line.split(":")
    label = label.strip()
    count = count.strip()
    
    for k,v in label_train_dic.items():
        if k == label:
            label_train_dic[k]=count

# %%
for k, v in label_train_dic.items():
    print("%s: %s" % (k, v))
# Out:
# 1914-1918_t: 3366
# 1918-1939_t: 121
# 1939-1945_t: 288
# 1945-1989_t: 248
# administration publique et développement_d: 125
# anthropologie politique_t: 126
# approches de corpus_t: 7054
# archives_t: 7054
# archéologie_d: 228
# arts et humanités_d: 1962
# arts_d: 132
# asie_t: 332
# bas moyen âge_t: 1057
# bibliothéconomie_d: 428
# biomédecine_d: 211
# chine_t: 150
# communication_d: 852
# conflits_t: 176
# digital humanities_t: 979
# enquêtes_t: 7054
# europe centrale et orientale_t: 397
# europe_t: 429
# france_t: 538
# guerres_t: 176
# haut moyen âge_t: 1196
# histoire culturelle_t: 1054
# histoire de l'art_t: 611
# histoire des religions_t: 442
# histoire des sciences sociales_d: 230
# histoire des sciences_t: 495
# histoire du droit_t: 223
# histoire et archéologie_d: 9892
# histoire et philosophie des sciences_d: 682
# histoire et sociologie des médias_t: 670
# histoire industrielle_t: 112
# histoire intellectuelle_t: 732
# histoire politique_t: 181
# histoire sociale_t: 815
# histoire urbaine_t: 554
# histoire économique_t: 143
# histoire_d: 7127
# histoire_t: 13377
# historiographie_t: 161
# humanités pluridisciplinaires_d: 3060
# information_t: 1511
# langage_t: 139
# langue et linguistique_d: 404
# linguistique appliquée_d: 138
# linguistique_t: 304
# littérature_d: 204
# littératures_t: 193
# monde germanique_t: 2397
# moyen âge_t: 1054
# musique_d: 180
# méthodes de traitement et de représentation_t: 141
# patrimoine_t: 1224
# pays baltes et scandinaves_t: 162
# pensée_t: 142
# philosophie_d: 168
# philosophie_t: 140
# pluridisciplinarité_d: 3102
# prospectives_t: 801
# psychisme_t: 252
# psychologie expérimentale_d: 112
# psychologie_d: 140
# psychologie_t: 231
# relations internationales_t: 112
# religions_d: 755
# religions_t: 220
# représentations_t: 1092
# révolution française_t: 263
# sciences auxiliaires de l'histoire_t: 582
# sciences cognitives_t: 112
# sciences de l'information et bibliothéconomie_d: 274
# sciences de l'information et de la communication_d: 428
# sciences de l'information_t: 492
# sciences de l'éducation_t: 274
# sciences politiques_d: 569
# sciences sociales interdisciplinaires_d: 9225
# sociologie de la culture_t: 813
# sociologie des religions_t: 137
# sociologie des sciences_t: 470
# sociologie du travail_t: 774
# sociologie et anthropologie_d: 635
# sociologie urbaine_t: 625
# sociologie économique_t: 541
# sociologie_d: 504
# sociologie_t: 563
# travail social et politique sociale_d: 138
# travail social_d: 262
# vie de la recherche_t: 460
# violence_t: 176
# xvie siècle_t: 246
# xviie siècle_t: 1252
# xviiie siècle_t: 1056
# xxe siècle_t: 198
# xxie siècle_t: 226
# âges de la vie_t: 248
# économie_d: 109
# édition électronique_t: 1043
# éducation et sciences de l'éducation_d: 135
# éducation spécialisée_d: 383
# éducation_d: 766
# éducation_t: 481
# épistémologie et méthodes_t: 555
# époque contemporaine_t: 3647
# époque moderne_t: 682
# étude des genres_t: 211
# études anciennes_d: 169
# études asiatiques_d: 268
# études des sciences_t: 738
# études régionales_d: 229
# études sur la famille_d: 134
# études visuelles_t: 376

# %%
label_keys = label_dic.keys()
label_train_count = label_train_dic.values()
label_count = label_dic.values()
pred_count = pred_dic.values()
correct_count = correct_predicted.values()
correct_percent = correct_predicted_prozent.values()
false_count = false_predicted.values()
false_percent = false_predicted_prozent.values()
not_pred_count = not_predicted.values()
not_pred_percent = not_predicted_prozent.values()

with open('../MLP/MLP_all_labels_prozentuale_auswertung.txt', 'w+', encoding="utf-8") as file:
    file.write("Label (all_labels), Trainingsset (#), Testset (#), Vorhersagen (#), Korrekte Vorhersagen (#), Korrekte Vorhersagen (%), Falsche Vorhersagen (#), Falsche Vorhersagen (%), Nicht vorhergesagte Labels (#), Nicht vorhergesagte Labels (%)\n")
    for key, train_count, test_count, pred_count, correct_count, correct_percent, false_count, false_percent, not_pred_count, not_pred_percent in zip(label_keys, label_train_count, label_count, pred_count, correct_count, correct_percent, false_count, false_percent, not_pred_count, not_pred_percent):
        print("%s, %s, %s, %s, %s, %s%%, %s, %s%%, %s, %s%%" % (key, train_count, test_count, pred_count, correct_count, correct_percent, false_count, false_percent, not_pred_count, not_pred_percent))
        file.write("%s, %s, %s, %s, %s, %s%%, %s, %s%%, %s, %s%%\n" % (key, train_count, test_count, pred_count, correct_count, correct_percent, false_count, false_percent, not_pred_count, not_pred_percent))
# Out:
# 1914-1918_t, 3366, 674, 628, 612, 97.45%, 16, 2.55%, 62, 9.2%
# 1918-1939_t, 121, 24, 9, 9, 100.0%, 0, 0.0%, 15, 62.5%
# 1939-1945_t, 288, 58, 30, 26, 86.67%, 4, 13.33%, 32, 55.17%
# 1945-1989_t, 248, 49, 31, 28, 90.32%, 3, 9.68%, 21, 42.86%
# administration publique et développement_d, 125, 25, 14, 12, 85.71%, 2, 14.29%, 13, 52.0%
# anthropologie politique_t, 126, 25, 16, 11, 68.75%, 5, 31.25%, 14, 56.0%
# approches de corpus_t, 7054, 1412, 1219, 1110, 91.06%, 109, 8.94%, 302, 21.39%
# archives_t, 7054, 1412, 1234, 1119, 90.68%, 115, 9.32%, 293, 20.75%
# archéologie_d, 228, 45, 28, 23, 82.14%, 5, 17.86%, 22, 48.89%
# arts et humanités_d, 1962, 389, 280, 219, 78.21%, 61, 21.79%, 170, 43.7%
# arts_d, 132, 27, 12, 12, 100.0%, 0, 0.0%, 15, 55.56%
# asie_t, 332, 67, 46, 46, 100.0%, 0, 0.0%, 21, 31.34%
# bas moyen âge_t, 1057, 212, 178, 122, 68.54%, 56, 31.46%, 90, 42.45%
# bibliothéconomie_d, 428, 85, 27, 26, 96.3%, 1, 3.7%, 59, 69.41%
# biomédecine_d, 211, 42, 26, 26, 100.0%, 0, 0.0%, 16, 38.1%
# chine_t, 150, 30, 9, 8, 88.89%, 1, 11.11%, 22, 73.33%
# communication_d, 852, 170, 81, 69, 85.19%, 12, 14.81%, 101, 59.41%
# conflits_t, 176, 36, 18, 17, 94.44%, 1, 5.56%, 19, 52.78%
# digital humanities_t, 979, 196, 130, 100, 76.92%, 30, 23.08%, 96, 48.98%
# enquêtes_t, 7054, 1412, 1232, 1116, 90.58%, 116, 9.42%, 296, 20.96%
# europe centrale et orientale_t, 397, 80, 49, 45, 91.84%, 4, 8.16%, 35, 43.75%
# europe_t, 429, 86, 49, 42, 85.71%, 7, 14.29%, 44, 51.16%
# france_t, 538, 107, 49, 40, 81.63%, 9, 18.37%, 67, 62.62%
# guerres_t, 176, 36, 18, 17, 94.44%, 1, 5.56%, 19, 52.78%
# haut moyen âge_t, 1196, 240, 223, 155, 69.51%, 68, 30.49%, 85, 35.42%
# histoire culturelle_t, 1054, 209, 148, 123, 83.11%, 25, 16.89%, 86, 41.15%
# histoire de l'art_t, 611, 120, 80, 69, 86.25%, 11, 13.75%, 51, 42.5%
# histoire des religions_t, 442, 88, 46, 42, 91.3%, 4, 8.7%, 46, 52.27%
# histoire des sciences sociales_d, 230, 46, 8, 8, 100.0%, 0, 0.0%, 38, 82.61%
# histoire des sciences_t, 495, 100, 58, 55, 94.83%, 3, 5.17%, 45, 45.0%
# histoire du droit_t, 223, 44, 28, 28, 100.0%, 0, 0.0%, 16, 36.36%
# histoire et archéologie_d, 9892, 1978, 1947, 1660, 85.26%, 287, 14.74%, 318, 16.08%
# histoire et philosophie des sciences_d, 682, 136, 90, 59, 65.56%, 31, 34.44%, 77, 56.62%
# histoire et sociologie des médias_t, 670, 134, 67, 57, 85.07%, 10, 14.93%, 77, 57.46%
# histoire industrielle_t, 112, 22, 0, 0, 0%, 0, 0%, 22, 100.0%
# histoire intellectuelle_t, 732, 146, 78, 65, 83.33%, 13, 16.67%, 81, 55.48%
# histoire politique_t, 181, 35, 4, 4, 100.0%, 0, 0.0%, 31, 88.57%
# histoire sociale_t, 815, 162, 64, 47, 73.44%, 17, 26.56%, 115, 70.99%
# histoire urbaine_t, 554, 111, 53, 46, 86.79%, 7, 13.21%, 65, 58.56%
# histoire économique_t, 143, 28, 0, 0, 0%, 0, 0%, 28, 100.0%
# histoire_d, 7127, 1427, 1357, 1155, 85.11%, 202, 14.89%, 272, 19.06%
# histoire_t, 13377, 2677, 2716, 2455, 90.39%, 261, 9.61%, 222, 8.29%
# historiographie_t, 161, 32, 18, 13, 72.22%, 5, 27.78%, 19, 59.38%
# humanités pluridisciplinaires_d, 3060, 614, 466, 355, 76.18%, 111, 23.82%, 259, 42.18%
# information_t, 1511, 302, 256, 186, 72.66%, 70, 27.34%, 116, 38.41%
# langage_t, 139, 27, 12, 11, 91.67%, 1, 8.33%, 16, 59.26%
# langue et linguistique_d, 404, 80, 44, 42, 95.45%, 2, 4.55%, 38, 47.5%
# linguistique appliquée_d, 138, 27, 12, 11, 91.67%, 1, 8.33%, 16, 59.26%
# linguistique_t, 304, 60, 28, 26, 92.86%, 2, 7.14%, 34, 56.67%
# littérature_d, 204, 42, 18, 18, 100.0%, 0, 0.0%, 24, 57.14%
# littératures_t, 193, 39, 21, 20, 95.24%, 1, 4.76%, 19, 48.72%
# monde germanique_t, 2397, 478, 415, 298, 71.81%, 117, 28.19%, 180, 37.66%
# moyen âge_t, 1054, 211, 161, 140, 86.96%, 21, 13.04%, 71, 33.65%
# musique_d, 180, 36, 12, 11, 91.67%, 1, 8.33%, 25, 69.44%
# méthodes de traitement et de représentation_t, 141, 28, 19, 19, 100.0%, 0, 0.0%, 9, 32.14%
# patrimoine_t, 1224, 245, 167, 117, 70.06%, 50, 29.94%, 128, 52.24%
# pays baltes et scandinaves_t, 162, 33, 23, 23, 100.0%, 0, 0.0%, 10, 30.3%
# pensée_t, 142, 28, 9, 8, 88.89%, 1, 11.11%, 20, 71.43%
# philosophie_d, 168, 34, 19, 17, 89.47%, 2, 10.53%, 17, 50.0%
# philosophie_t, 140, 27, 9, 9, 100.0%, 0, 0.0%, 18, 66.67%
# pluridisciplinarité_d, 3102, 621, 534, 379, 70.97%, 155, 29.03%, 242, 38.97%
# prospectives_t, 801, 160, 53, 43, 81.13%, 10, 18.87%, 117, 73.12%
# psychisme_t, 252, 50, 39, 38, 97.44%, 1, 2.56%, 12, 24.0%
# psychologie expérimentale_d, 112, 22, 9, 9, 100.0%, 0, 0.0%, 13, 59.09%
# psychologie_d, 140, 28, 20, 20, 100.0%, 0, 0.0%, 8, 28.57%
# psychologie_t, 231, 46, 31, 30, 96.77%, 1, 3.23%, 16, 34.78%
# relations internationales_t, 112, 22, 1, 1, 100.0%, 0, 0.0%, 21, 95.45%
# religions_d, 755, 151, 85, 71, 83.53%, 14, 16.47%, 80, 52.98%
# religions_t, 220, 44, 33, 32, 96.97%, 1, 3.03%, 12, 27.27%
# représentations_t, 1092, 217, 125, 104, 83.2%, 21, 16.8%, 113, 52.07%
# révolution française_t, 263, 53, 23, 22, 95.65%, 1, 4.35%, 31, 58.49%
# sciences auxiliaires de l'histoire_t, 582, 117, 87, 62, 71.26%, 25, 28.74%, 55, 47.01%
# sciences cognitives_t, 112, 22, 9, 9, 100.0%, 0, 0.0%, 13, 59.09%
# sciences de l'information et bibliothéconomie_d, 274, 53, 21, 21, 100.0%, 0, 0.0%, 32, 60.38%
# sciences de l'information et de la communication_d, 428, 85, 27, 26, 96.3%, 1, 3.7%, 59, 69.41%
# sciences de l'information_t, 492, 98, 55, 43, 78.18%, 12, 21.82%, 55, 56.12%
# sciences de l'éducation_t, 274, 56, 40, 35, 87.5%, 5, 12.5%, 21, 37.5%
# sciences politiques_d, 569, 114, 61, 49, 80.33%, 12, 19.67%, 65, 57.02%
# sciences sociales interdisciplinaires_d, 9225, 1846, 1882, 1576, 83.74%, 306, 16.26%, 270, 14.63%
# sociologie de la culture_t, 813, 163, 102, 89, 87.25%, 13, 12.75%, 74, 45.4%
# sociologie des religions_t, 137, 28, 19, 16, 84.21%, 3, 15.79%, 12, 42.86%
# sociologie des sciences_t, 470, 93, 56, 46, 82.14%, 10, 17.86%, 47, 50.54%
# sociologie du travail_t, 774, 155, 124, 104, 83.87%, 20, 16.13%, 51, 32.9%
# sociologie et anthropologie_d, 635, 127, 74, 66, 89.19%, 8, 10.81%, 61, 48.03%
# sociologie urbaine_t, 625, 125, 86, 77, 89.53%, 9, 10.47%, 48, 38.4%
# sociologie économique_t, 541, 108, 68, 63, 92.65%, 5, 7.35%, 45, 41.67%
# sociologie_d, 504, 101, 51, 41, 80.39%, 10, 19.61%, 60, 59.41%
# sociologie_t, 563, 113, 84, 73, 86.9%, 11, 13.1%, 40, 35.4%
# travail social et politique sociale_d, 138, 28, 26, 22, 84.62%, 4, 15.38%, 6, 21.43%
# travail social_d, 262, 53, 41, 39, 95.12%, 2, 4.88%, 14, 26.42%
# vie de la recherche_t, 460, 93, 59, 54, 91.53%, 5, 8.47%, 39, 41.94%
# violence_t, 176, 36, 18, 17, 94.44%, 1, 5.56%, 19, 52.78%
# xvie siècle_t, 246, 49, 9, 9, 100.0%, 0, 0.0%, 40, 81.63%
# xviie siècle_t, 1252, 251, 200, 143, 71.5%, 57, 28.5%, 108, 43.03%
# xviiie siècle_t, 1056, 212, 152, 109, 71.71%, 43, 28.29%, 103, 48.58%
# xxe siècle_t, 198, 39, 6, 5, 83.33%, 1, 16.67%, 34, 87.18%
# xxie siècle_t, 226, 45, 28, 28, 100.0%, 0, 0.0%, 17, 37.78%
# âges de la vie_t, 248, 50, 38, 33, 86.84%, 5, 13.16%, 17, 34.0%
# économie_d, 109, 21, 2, 2, 100.0%, 0, 0.0%, 19, 90.48%
# édition électronique_t, 1043, 208, 124, 98, 79.03%, 26, 20.97%, 110, 52.88%
# éducation et sciences de l'éducation_d, 135, 27, 8, 7, 87.5%, 1, 12.5%, 20, 74.07%
# éducation spécialisée_d, 383, 77, 54, 50, 92.59%, 4, 7.41%, 27, 35.06%
# éducation_d, 766, 155, 98, 86, 87.76%, 12, 12.24%, 69, 44.52%
# éducation_t, 481, 97, 56, 50, 89.29%, 6, 10.71%, 47, 48.45%
# épistémologie et méthodes_t, 555, 112, 59, 52, 88.14%, 7, 11.86%, 60, 53.57%
# époque contemporaine_t, 3647, 730, 641, 617, 96.26%, 24, 3.74%, 113, 15.48%
# époque moderne_t, 682, 138, 83, 74, 89.16%, 9, 10.84%, 64, 46.38%
# étude des genres_t, 211, 42, 26, 26, 100.0%, 0, 0.0%, 16, 38.1%
# études anciennes_d, 169, 34, 9, 9, 100.0%, 0, 0.0%, 25, 73.53%
# études asiatiques_d, 268, 54, 36, 34, 94.44%, 2, 5.56%, 20, 37.04%
# études des sciences_t, 738, 148, 97, 77, 79.38%, 20, 20.62%, 71, 47.97%
# études régionales_d, 229, 46, 25, 25, 100.0%, 0, 0.0%, 21, 45.65%
# études sur la famille_d, 134, 28, 4, 4, 100.0%, 0, 0.0%, 24, 85.71%
# études visuelles_t, 376, 75, 40, 39, 97.5%, 1, 2.5%, 36, 48.0%
