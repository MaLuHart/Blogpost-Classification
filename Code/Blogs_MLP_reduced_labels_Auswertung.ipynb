# %% [markdown]
# # Auswertung der Klassifikation mit dem MLPClassifier (reduced_labels)
#
# Autorin: Maria Hartmann

# %%
# read predicitons
f = open('../MLP/MLP_reduced_labels_predictions.txt', "r", encoding="utf-8")
lines = f.readlines()
f.close()
trues = []
preds = []
idents = []
labellist = []
for line in lines:
    if line.startswith("TRUE:"):
        line = line.replace("TRUE: ", "").strip()
        #trues.append(line.split(", "))
        labels = line.split(", ")
        tmp_line=[]
        for label in labels:
            label = label.strip().replace(",", "").strip()
            tmp_line.append(label)
        trues.append(tmp_line)
        labellist.append(tmp_line)
        
    elif line.startswith("PRED:"):
        line = line.replace("PRED: ", "").strip()
        #preds.append(line.split(","))
        labels = line.split(", ")
        tmp_line=[]
        for label in labels:
            label = label.strip().replace(",", "").strip()
            tmp_line.append(label)
        preds.append(tmp_line)
        if len(line) != 0:
            labellist.append(tmp_line)
    elif ".txt" in line:
        idents.append(line)
        
    else:
        continue

labelset = sorted(set([item for sublist in labellist for item in sublist]))

# %%
pred_count=0 #Anzal der Vorhersagen insgesamt
label_count=0 # Anzahl der Labels im Testset
false_count=0 # Anzal der falschen Vorhersagen (falsche Vorhersagen sind Vorhersagen, die nicht in den richtigen Labels enthalten sind)
right_count=0 # Anzal der richtigen Vorhersagen
not_pred_count=0 # Anzahl der nicht vorhergesagten Labels
pred_dic=dict(zip(labelset, [0]*len(labelset))) # Vorkommen der Labels in den Vorhersagen
label_dic=dict(zip(labelset, [0]*len(labelset))) # Vorkommen der Labels im Testset
correct_predicted=dict(zip(labelset, [0]*len(labelset))) # Richtige Vorhersagen und ihre Vorkommen
false_predicted=dict(zip(labelset, [0]*len(labelset))) # Falsche Vorhersagen und ihre Vorkommen
not_predicted=dict(zip(labelset, [0]*len(labelset))) # nicht vorhergesagt Labels und die Anzahl ihrer nicht Vorhersagen

for ident, true, pred in zip(idents, trues, preds):
    for t in true:
        label_count+=1
        if t in label_dic:
            label_dic[t]+=1
        else:
            #label_dic[t]=1
            print("Label im Dictionary nicht gefunden")
        if t not in pred:
            not_pred_count+=1
            if t in not_predicted:
                not_predicted[t]+=1
            else:
                #not_predicted[t]=1
                print("Label im Dictionary nicht gefunden")
        else:
            right_count+=1
            if t in correct_predicted:
                correct_predicted[t]+=1
            else:
                #false_predicted[t]=1
                print("Label im Dictionary nicht gefunden")
                
    for p in pred:
        if len(p) != 0:
            pred_count+=1
            if p in pred_dic:
                pred_dic[p]+=1
            else:
                #pred_dic[t]=1
                print("Label im Dictionary nicht gefunden")
            if p not in true:
                false_count+=1
                if p in false_predicted:
                    false_predicted[p]+=1
                else:
                    #false_predicted[p]=1
                    print("Label im Dictionary nicht gefunden")
        else:
            continue

# %%
# Gesamte Labels im Testset
print(len(label_dic))
for k, v in label_dic.items():
    print("%s: %s" % (k, v))
    
#labels = [(k, label_dic[k]) for k in sorted(label_dic, key=label_dic.get, reverse=True)]
#for k, v in labels:
    #print("%s: %s" % (k, v))
# Out:
# 35
# administration publique et développement_d: 129
# anthropologie_t: 42
# arts et humanités_d: 971
# asie_t: 67
# bibliothéconomie_d: 249
# droit_t: 55
# ethnologie_t: 42
# europe_t: 648
# géographie_t: 40
# histoire et archéologie_d: 3298
# histoire_t: 2833
# information_t: 560
# langage_t: 99
# langue et linguistique_d: 82
# littérature_d: 42
# moyen âge_t: 322
# pensée_t: 190
# pluridisciplinarité_d: 2128
# psychisme_t: 50
# psychologie_d: 50
# religions_t: 136
# représentations_t: 573
# sciences de l'information et de la communication_d: 249
# sciences de la santé et de la santé publique_d: 42
# sciences politiques_d: 129
# sociologie et anthropologie_d: 288
# sociologie_t: 370
# travail social et politique sociale_d: 112
# éducation_d: 203
# éducation_t: 152
# épistémologie et méthodes_t: 1787
# époque contemporaine_t: 1027
# époque moderne_t: 302
# études des sciences_t: 263
# études du politique_t: 113

# %%
# Gesamte Vorhersagen im Testset
print(len(pred_dic))
for k, v in pred_dic.items():
    print("%s: %s" % (k, v))
# Out:
# 35
# administration publique et développement_d: 50
# anthropologie_t: 9
# arts et humanités_d: 928
# asie_t: 45
# bibliothéconomie_d: 143
# droit_t: 27
# ethnologie_t: 9
# europe_t: 541
# géographie_t: 11
# histoire et archéologie_d: 3434
# histoire_t: 3012
# information_t: 431
# langage_t: 57
# langue et linguistique_d: 47
# littérature_d: 12
# moyen âge_t: 283
# pensée_t: 111
# pluridisciplinarité_d: 2127
# psychisme_t: 28
# psychologie_d: 29
# religions_t: 76
# représentations_t: 390
# sciences de l'information et de la communication_d: 142
# sciences de la santé et de la santé publique_d: 27
# sciences politiques_d: 50
# sociologie et anthropologie_d: 203
# sociologie_t: 323
# travail social et politique sociale_d: 88
# éducation_d: 178
# éducation_t: 106
# épistémologie et méthodes_t: 1744
# époque contemporaine_t: 936
# époque moderne_t: 242
# études des sciences_t: 188
# études du politique_t: 37

# %%
# Korrekte Vorhersagen je Label im Korpus
print(len(correct_predicted))
for k, v in correct_predicted.items():
    print("%s: %s" % (k, v))
# Out:
# 35
# administration publique et développement_d: 46
# anthropologie_t: 9
# arts et humanités_d: 690
# asie_t: 45
# bibliothéconomie_d: 108
# droit_t: 27
# ethnologie_t: 9
# europe_t: 401
# géographie_t: 9
# histoire et archéologie_d: 3129
# histoire_t: 2710
# information_t: 323
# langage_t: 50
# langue et linguistique_d: 45
# littérature_d: 11
# moyen âge_t: 218
# pensée_t: 98
# pluridisciplinarité_d: 1813
# psychisme_t: 27
# psychologie_d: 28
# religions_t: 73
# représentations_t: 302
# sciences de l'information et de la communication_d: 110
# sciences de la santé et de la santé publique_d: 27
# sciences politiques_d: 46
# sociologie et anthropologie_d: 177
# sociologie_t: 272
# travail social et politique sociale_d: 81
# éducation_d: 134
# éducation_t: 97
# épistémologie et méthodes_t: 1499
# époque contemporaine_t: 836
# époque moderne_t: 186
# études des sciences_t: 139
# études du politique_t: 34

# %%
# Falsche Vorhersagen je Label im Korpus
print(len(false_predicted))
for k, v in false_predicted.items():
    print("%s: %s" % (k, v))
# Out:
# 35
# administration publique et développement_d: 4
# anthropologie_t: 0
# arts et humanités_d: 238
# asie_t: 0
# bibliothéconomie_d: 35
# droit_t: 0
# ethnologie_t: 0
# europe_t: 140
# géographie_t: 2
# histoire et archéologie_d: 305
# histoire_t: 302
# information_t: 108
# langage_t: 7
# langue et linguistique_d: 2
# littérature_d: 1
# moyen âge_t: 65
# pensée_t: 13
# pluridisciplinarité_d: 314
# psychisme_t: 1
# psychologie_d: 1
# religions_t: 3
# représentations_t: 88
# sciences de l'information et de la communication_d: 32
# sciences de la santé et de la santé publique_d: 0
# sciences politiques_d: 4
# sociologie et anthropologie_d: 26
# sociologie_t: 51
# travail social et politique sociale_d: 7
# éducation_d: 44
# éducation_t: 9
# épistémologie et méthodes_t: 245
# époque contemporaine_t: 100
# époque moderne_t: 56
# études des sciences_t: 49
# études du politique_t: 3

# %%
# nicht vorhergesagte Labels im Korpus
print(len(not_predicted))
for k, v in not_predicted.items():
    print("%s: %s" % (k, v))
# Out:
# 35
# administration publique et développement_d: 83
# anthropologie_t: 33
# arts et humanités_d: 281
# asie_t: 22
# bibliothéconomie_d: 141
# droit_t: 28
# ethnologie_t: 33
# europe_t: 247
# géographie_t: 31
# histoire et archéologie_d: 169
# histoire_t: 123
# information_t: 237
# langage_t: 49
# langue et linguistique_d: 37
# littérature_d: 31
# moyen âge_t: 104
# pensée_t: 92
# pluridisciplinarité_d: 315
# psychisme_t: 23
# psychologie_d: 22
# religions_t: 63
# représentations_t: 271
# sciences de l'information et de la communication_d: 139
# sciences de la santé et de la santé publique_d: 15
# sciences politiques_d: 83
# sociologie et anthropologie_d: 111
# sociologie_t: 98
# travail social et politique sociale_d: 31
# éducation_d: 69
# éducation_t: 55
# épistémologie et méthodes_t: 288
# époque contemporaine_t: 191
# époque moderne_t: 116
# études des sciences_t: 124
# études du politique_t: 79

# %% [markdown]
# PROZENTUALE AUSWERTUNG:
#
# Prozentsatz = (Prozentwert/Grundwert)*100
#
#
# label_dic = correct_predicted + not_predicted
#
# pred_dic = correct_predicted + false_predicted

# %%
# nicht vorhergesagte Labels in Prozent
not_predicted_prozent={}
for key, value in label_dic.items():
    for not_k, not_v in not_predicted.items():
        if not_k == key:
            prozent=round(((not_v/value)*100),2)
            not_predicted_prozent[not_k]=prozent
            
for k, v in not_predicted_prozent.items():
    print("%s: %s%%" % (k, v))
# Out:
# administration publique et développement_d: 64.34%
# anthropologie_t: 78.57%
# arts et humanités_d: 28.94%
# asie_t: 32.84%
# bibliothéconomie_d: 56.63%
# droit_t: 50.91%
# ethnologie_t: 78.57%
# europe_t: 38.12%
# géographie_t: 77.5%
# histoire et archéologie_d: 5.12%
# histoire_t: 4.34%
# information_t: 42.32%
# langage_t: 49.49%
# langue et linguistique_d: 45.12%
# littérature_d: 73.81%
# moyen âge_t: 32.3%
# pensée_t: 48.42%
# pluridisciplinarité_d: 14.8%
# psychisme_t: 46.0%
# psychologie_d: 44.0%
# religions_t: 46.32%
# représentations_t: 47.29%
# sciences de l'information et de la communication_d: 55.82%
# sciences de la santé et de la santé publique_d: 35.71%
# sciences politiques_d: 64.34%
# sociologie et anthropologie_d: 38.54%
# sociologie_t: 26.49%
# travail social et politique sociale_d: 27.68%
# éducation_d: 33.99%
# éducation_t: 36.18%
# épistémologie et méthodes_t: 16.12%
# époque contemporaine_t: 18.6%
# époque moderne_t: 38.41%
# études des sciences_t: 47.15%
# études du politique_t: 69.91%

# %%
# Fehlklassifizierungsrate je Label in Prozent
false_predicted_prozent={}
for key, value in pred_dic.items():
    for false_k, false_v in false_predicted.items():
        if false_k == key:
            prozent=round(((false_v/value)*100),2)
            false_predicted_prozent[false_k]=prozent
            
for k, v in false_predicted_prozent.items():
    print("%s: %s%%" % (k, v))
# Out:
# administration publique et développement_d: 8.0%
# anthropologie_t: 0.0%
# arts et humanités_d: 25.65%
# asie_t: 0.0%
# bibliothéconomie_d: 24.48%
# droit_t: 0.0%
# ethnologie_t: 0.0%
# europe_t: 25.88%
# géographie_t: 18.18%
# histoire et archéologie_d: 8.88%
# histoire_t: 10.03%
# information_t: 25.06%
# langage_t: 12.28%
# langue et linguistique_d: 4.26%
# littérature_d: 8.33%
# moyen âge_t: 22.97%
# pensée_t: 11.71%
# pluridisciplinarité_d: 14.76%
# psychisme_t: 3.57%
# psychologie_d: 3.45%
# religions_t: 3.95%
# représentations_t: 22.56%
# sciences de l'information et de la communication_d: 22.54%
# sciences de la santé et de la santé publique_d: 0.0%
# sciences politiques_d: 8.0%
# sociologie et anthropologie_d: 12.81%
# sociologie_t: 15.79%
# travail social et politique sociale_d: 7.95%
# éducation_d: 24.72%
# éducation_t: 8.49%
# épistémologie et méthodes_t: 14.05%
# époque contemporaine_t: 10.68%
# époque moderne_t: 23.14%
# études des sciences_t: 26.06%
# études du politique_t: 8.11%

# %%
# Korrektklassifizierungsrate je Label in Prozent
correct_predicted_prozent={}
for key, value in pred_dic.items():
    for correct_k, correct_v in correct_predicted.items():
        if correct_k == key:
            prozent=round(((correct_v/value)*100),2)
            correct_predicted_prozent[correct_k]=prozent
            
for k, v in correct_predicted_prozent.items():
    print("%s: %s%%" % (k, v))
# Out:
# administration publique et développement_d: 92.0%
# anthropologie_t: 100.0%
# arts et humanités_d: 74.35%
# asie_t: 100.0%
# bibliothéconomie_d: 75.52%
# droit_t: 100.0%
# ethnologie_t: 100.0%
# europe_t: 74.12%
# géographie_t: 81.82%
# histoire et archéologie_d: 91.12%
# histoire_t: 89.97%
# information_t: 74.94%
# langage_t: 87.72%
# langue et linguistique_d: 95.74%
# littérature_d: 91.67%
# moyen âge_t: 77.03%
# pensée_t: 88.29%
# pluridisciplinarité_d: 85.24%
# psychisme_t: 96.43%
# psychologie_d: 96.55%
# religions_t: 96.05%
# représentations_t: 77.44%
# sciences de l'information et de la communication_d: 77.46%
# sciences de la santé et de la santé publique_d: 100.0%
# sciences politiques_d: 92.0%
# sociologie et anthropologie_d: 87.19%
# sociologie_t: 84.21%
# travail social et politique sociale_d: 92.05%
# éducation_d: 75.28%
# éducation_t: 91.51%
# épistémologie et méthodes_t: 85.95%
# époque contemporaine_t: 89.32%
# époque moderne_t: 76.86%
# études des sciences_t: 73.94%
# études du politique_t: 91.89%

# %% [markdown]
# Ergebnisse in Datei schreiben

# %%
f = open('../Preprocessing/blogposts_per_reduced_labels_reduced.txt', "r", encoding="utf-8")
lines = f.readlines()
f.close()

label_train_dic=dict(zip(labelset, [0]*len(labelset))) # Vorkommen der Labels im Testset

for line in lines:
    label, count = line.split(":")
    label = label.strip()
    count = count.strip()
    
    for k,v in label_train_dic.items():
        if k == label:
            label_train_dic[k]=count

# %%
for k, v in label_train_dic.items():
    print("%s: %s" % (k, v))
# Out:
# administration publique et développement_d: 644
# anthropologie_t: 215
# arts et humanités_d: 4863
# asie_t: 332
# bibliothéconomie_d: 1252
# droit_t: 279
# ethnologie_t: 215
# europe_t: 3240
# géographie_t: 201
# histoire et archéologie_d: 16471
# histoire_t: 14155
# information_t: 2809
# langage_t: 497
# langue et linguistique_d: 414
# littérature_d: 204
# moyen âge_t: 1608
# pensée_t: 960
# pluridisciplinarité_d: 10635
# psychisme_t: 252
# psychologie_d: 252
# religions_t: 678
# représentations_t: 2874
# sciences de l'information et de la communication_d: 1252
# sciences de la santé et de la santé publique_d: 211
# sciences politiques_d: 644
# sociologie et anthropologie_d: 1440
# sociologie_t: 1848
# travail social et politique sociale_d: 553
# éducation_d: 1011
# éducation_t: 758
# épistémologie et méthodes_t: 8927
# époque contemporaine_t: 5130
# époque moderne_t: 1505
# études des sciences_t: 1314
# études du politique_t: 568

# %%
label_keys = label_dic.keys()
label_train_count = label_train_dic.values()
label_count = label_dic.values()
pred_count = pred_dic.values()
correct_count = correct_predicted.values()
correct_percent = correct_predicted_prozent.values()
false_count = false_predicted.values()
false_percent = false_predicted_prozent.values()
not_pred_count = not_predicted.values()
not_pred_percent = not_predicted_prozent.values()

with open('../MLP/MLP_reduced_labels_prozentuale_auswertung.txt', 'w+', encoding="utf-8") as file:
    file.write("Label (reduced_labels), Trainingsset (#), Testset (#), Vorhersagen (#), Korrekte Vorhersagen (#), Korrekte Vorhersagen (%), Falsche Vorhersagen (#), Falsche Vorhersagen (%), Nicht vorhergesagte Labels (#), Nicht vorhergesagte Labels (%)\n")
    for key, train_count, test_count, pred_count, correct_count, correct_percent, false_count, false_percent, not_pred_count, not_pred_percent in zip(label_keys, label_train_count, label_count, pred_count, correct_count, correct_percent, false_count, false_percent, not_pred_count, not_pred_percent):
        print("%s, %s, %s, %s, %s, %s%%, %s, %s%%, %s, %s%%" % (key, train_count, test_count, pred_count, correct_count, correct_percent, false_count, false_percent, not_pred_count, not_pred_percent))
        file.write("%s, %s, %s, %s, %s, %s%%, %s, %s%%, %s, %s%%\n" % (key, train_count, test_count, pred_count, correct_count, correct_percent, false_count, false_percent, not_pred_count, not_pred_percent))
# Out:
# administration publique et développement_d, 644, 129, 50, 46, 92.0%, 4, 8.0%, 83, 64.34%
# anthropologie_t, 215, 42, 9, 9, 100.0%, 0, 0.0%, 33, 78.57%
# arts et humanités_d, 4863, 971, 928, 690, 74.35%, 238, 25.65%, 281, 28.94%
# asie_t, 332, 67, 45, 45, 100.0%, 0, 0.0%, 22, 32.84%
# bibliothéconomie_d, 1252, 249, 143, 108, 75.52%, 35, 24.48%, 141, 56.63%
# droit_t, 279, 55, 27, 27, 100.0%, 0, 0.0%, 28, 50.91%
# ethnologie_t, 215, 42, 9, 9, 100.0%, 0, 0.0%, 33, 78.57%
# europe_t, 3240, 648, 541, 401, 74.12%, 140, 25.88%, 247, 38.12%
# géographie_t, 201, 40, 11, 9, 81.82%, 2, 18.18%, 31, 77.5%
# histoire et archéologie_d, 16471, 3298, 3434, 3129, 91.12%, 305, 8.88%, 169, 5.12%
# histoire_t, 14155, 2833, 3012, 2710, 89.97%, 302, 10.03%, 123, 4.34%
# information_t, 2809, 560, 431, 323, 74.94%, 108, 25.06%, 237, 42.32%
# langage_t, 497, 99, 57, 50, 87.72%, 7, 12.28%, 49, 49.49%
# langue et linguistique_d, 414, 82, 47, 45, 95.74%, 2, 4.26%, 37, 45.12%
# littérature_d, 204, 42, 12, 11, 91.67%, 1, 8.33%, 31, 73.81%
# moyen âge_t, 1608, 322, 283, 218, 77.03%, 65, 22.97%, 104, 32.3%
# pensée_t, 960, 190, 111, 98, 88.29%, 13, 11.71%, 92, 48.42%
# pluridisciplinarité_d, 10635, 2128, 2127, 1813, 85.24%, 314, 14.76%, 315, 14.8%
# psychisme_t, 252, 50, 28, 27, 96.43%, 1, 3.57%, 23, 46.0%
# psychologie_d, 252, 50, 29, 28, 96.55%, 1, 3.45%, 22, 44.0%
# religions_t, 678, 136, 76, 73, 96.05%, 3, 3.95%, 63, 46.32%
# représentations_t, 2874, 573, 390, 302, 77.44%, 88, 22.56%, 271, 47.29%
# sciences de l'information et de la communication_d, 1252, 249, 142, 110, 77.46%, 32, 22.54%, 139, 55.82%
# sciences de la santé et de la santé publique_d, 211, 42, 27, 27, 100.0%, 0, 0.0%, 15, 35.71%
# sciences politiques_d, 644, 129, 50, 46, 92.0%, 4, 8.0%, 83, 64.34%
# sociologie et anthropologie_d, 1440, 288, 203, 177, 87.19%, 26, 12.81%, 111, 38.54%
# sociologie_t, 1848, 370, 323, 272, 84.21%, 51, 15.79%, 98, 26.49%
# travail social et politique sociale_d, 553, 112, 88, 81, 92.05%, 7, 7.95%, 31, 27.68%
# éducation_d, 1011, 203, 178, 134, 75.28%, 44, 24.72%, 69, 33.99%
# éducation_t, 758, 152, 106, 97, 91.51%, 9, 8.49%, 55, 36.18%
# épistémologie et méthodes_t, 8927, 1787, 1744, 1499, 85.95%, 245, 14.05%, 288, 16.12%
# époque contemporaine_t, 5130, 1027, 936, 836, 89.32%, 100, 10.68%, 191, 18.6%
# époque moderne_t, 1505, 302, 242, 186, 76.86%, 56, 23.14%, 116, 38.41%
# études des sciences_t, 1314, 263, 188, 139, 73.94%, 49, 26.06%, 124, 47.15%
# études du politique_t, 568, 113, 37, 34, 91.89%, 3, 8.11%, 79, 69.91%
